# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import json

import glob

# %%
def createActionPlot(folder_logs, filename_save):
    filenames_log = glob.glob( folder_logs + "/log_*.csv")

    csvList = []

    for file_ in filenames_log:
        df = pd.read_csv(file_,index_col=None, header=0)
        csvList.append(df)

    actions_1 = []
    actions_2 = []
    veh_speeds_1 = []
    veh_speeds_2 = []
    veh_poss_1 = []
    veh_poss_2 = []
    curr_rewards_1 = []
    curr_rewards_2 = []
    times = []

    for csv in csvList:
        actions_1.append(csv[['action_acc_1']].values)
        actions_2.append(csv[['action_acc_2']].values)
        veh_speeds_1.append(csv[['veh_speed_1']].values)
        veh_speeds_2.append(csv[['veh_speed_2']].values)
        veh_poss_1.append(csv[['veh_pos_1']].values)
        veh_poss_2.append(csv[['veh_pos_2']].values)
        curr_rewards_1.append(csv[['curr_reward_1']].values)
        curr_rewards_2.append(csv[['curr_reward_2']].values)
        times.append(np.arange(csv[['action_acc_1']].values.size)/10)
   
    N_RA = 10
    pltAlpha = 0.15

    # print action
    for time, action_1 in zip(times,actions_1):
        plt.plot(time[:-1],
                 action_1[:-1],
                 c='b',
                 alpha=pltAlpha)
    for time, action_2 in zip(times,actions_2):
        plt.plot(time[:-1],
                 action_2[:-1],
                 c='r',
                 alpha=pltAlpha)

    # print action with rolling avg
    for time, action_1 in zip(times,actions_1):
        action_1_RA = np.convolve(action_1[:,0],np.ones((N_RA,))/N_RA,mode='valid')
        plt.plot(time[N_RA//2:-N_RA//2],
                 action_1_RA[:-1],
                 c='b')
    for time, action_2 in zip(times,actions_2):
        action_2_RA = np.convolve(action_2[:,0],np.ones((N_RA,))/N_RA,mode='valud')
        plt.plot(time[N_RA//2:-N_RA//2],
                 action_2_RA[:-1],
                 c='r')    
    
    plt.xlabel('time [s]')
    plt.ylabel('action_acc [m/s^2]')
    plt.grid()
    plt.ylim(-3.5,3.5)
    plt.xlim(-0.5,15)
    plt.title('Vergleich der Action beider Fahrzeuge (rolling Avg)')
    plt.savefig(filename_save)
    plt.clf()

# %%
import re
def natural_key(string_):
    """See http://www.codinghorror.com/blog/archives/001018.html"""
    return [int(s) if s.isdigit() else s for s in re.split(r'(\d+)', string_)]

# %%
path_ray_results = "/home/thorsten/ray_results/IntersectionExample/"
folder_results = "PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo"

folder_logs = glob.glob( path_ray_results+folder_results + "/results_run_*")
folder_logs = sorted(folder_logs,key=natural_key)
print(folder_logs)
i = 1
for folder_ in folder_logs:
    filename_save = path_ray_results+folder_results+"/action_"+str(i)+".png"
    createActionPlot(folder_,filename_save)
    i=i+1
# Out:
# ['/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_1', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_2', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_3', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_4', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_5', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_6', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_7', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_8', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_9', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_10', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_11', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_12', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_13', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_14', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_15', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_16', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_17', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_18', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_19', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_20', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_21', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_22', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_23', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_24', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_25', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_26', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_27', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_28', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_29', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_30', '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/results_run_31', '/home/thorsten/ray_results/Intersection ...

# %%
! ffmpeg -r 50 -i /home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/action_%d.png -c:v qtrle -pix_fmt rgb24 action.mov
# Out:
# ffmpeg version 2.8.15-0ubuntu0.16.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.10) 20160609
#   configuration: --prefix=/usr --extra-version=0ubuntu0.16.04.1 --build-suffix=-ffmpeg --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --cc=cc --cxx=g++ --enable-gpl --enable-shared --disable-stripping --disable-decoder=libopenjpeg --disable-decoder=libschroedinger --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librtmp --enable-libschroedinger --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxvid --enable-libzvbi --enable-openal --enable-opengl --enable-x11grab --enable-libdc1394 --enable-libiec61883 --enable-libzmq --enable-frei0r --enable-libx264 --enable-libopencv
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libavresample   2.  1.  0 /  2.  1.  0
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# Input #0, image2, from '/home/thorsten/ray_results/IntersectionExample/PPO_MultiAgentIntersectionEnv-v0_0_2019-02-22_00-55-50s2hylffo/action_%d.png':
#   Duration: 00:00:28.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 432x288 [SAR 2834:2834 DAR 3:2], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Output #0, mov, to 'action.mov':
#   Metadata:
#     encoder         : Lavf56.40.101
#     Stream #0:0: Video: qtrle (rle  / 0x20656C72), rgb24, 432x288 [SAR 1:1 DAR 3:2], q=2-31, 200 kb/s, 50 fps, 12800 tbn, 50 tbc
#     Metadata:
#       encoder         : Lavc56.60.100 qtrle
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> qtrle (native))
# Press [q] to stop, [?] for help
# Past duration 0.999992 too large
#     Last message repeated 164 timeses
# Past duration 0.999992 too large8kB time=00:00:03.34 bitrate=36884.4kbits/s dup=1 drop=0
#     Last message repeated 157 timeses
# Past duration 0.999992 too large8kB time=00:00:06.50 bitrate=28631.8kbits/s dup=1 drop=0
#     Last message repeated 185 timeses
# Past duration 0.999992 too large6kB time=00:00:10.22 bitrate=24468.7kbits/s dup=1 drop=0
#     Last message repeated 189 timeses
# frame=  701 fps=370 q=-0.0 Lsize=   36149kB time=00:00:14.02 bitrate=21122.2kbits/s dup=1 drop=0
# video:36145kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.011483%
