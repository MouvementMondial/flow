# %% [markdown]
# # Auswertung I3W
#
# Die Ergebnisse des Trainings wurden hier abgelegt:

# %%
path_ray_results = "/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_2"

# %% [markdown]
# ## A) Auswertung des Trainings
# Auswertung der csv, die während des Trainings erstellt worden ist.

# %%
import glob
filenames_progress = glob.glob( path_ray_results + "/*/progress.csv")
print(filenames_progress)
# Out:
# ['/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_2/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-12_20-26-29hvez1r1v/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_2/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-12_18-24-28tsnpscrn/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_2/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-12_22-27-15ke_66_iv/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_2/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-13_02-37-488i2grp5y3/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_2/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-13_04-38-5556_jtq95/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_2/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-13_00-37-03ula1uqx_/progress.csv']

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import json

progressList = []

for file_ in filenames_progress:
    df = pd.read_csv(file_,index_col=None, header=0)
    progressList.append(df)
    
episode_reward_mean = []

for progress in progressList:
    episode_reward_mean.append(progress[['episode_reward_mean']].values)
    
for reward_mean in episode_reward_mean:
    plt.plot(reward_mean)

plt.xlabel('iteration')
plt.ylabel('mean reward')
plt.grid()
plt.title('Training PPO')
plt.ylim(0,400)
plt.xlim(0,300)
# Out:
# (0, 300)
