# %% [markdown]
# # Auswertung I3W
#
# Die Ergebnisse des Trainings wurden hier abgelegt:

# %%
path_ray_results = "/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_4"

# %% [markdown]
# ## A) Auswertung des Trainings
# Auswertung der csv, die während des Trainings erstellt worden ist.

# %%
import glob
filenames_progress = glob.glob( path_ray_results + "/*/progress.csv")
print(filenames_progress)
# Out:
# ['/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_4/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-15_23-01-55in0lfhts/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_4/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-16_05-30-10a4o30o_v/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_4/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-16_03-52-41zi0ztudu/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_4/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-15_19-46-30g0u_vvol/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_4/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-16_07-06-459ng3s251/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_4/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-16_00-38-49cd6pa1wc/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_4/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-16_02-15-334agdw911/progress.csv', '/home/thorsten/ray_results/IntersectionExample/Reproduzierbarkeitstest_4/PPO_MultiAgentIntersectionEnv-v0_0_2019-03-15_21-24-22fzs0dk1f/progress.csv']

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import json

progressList = []

for file_ in filenames_progress:
    df = pd.read_csv(file_,index_col=None, header=0)
    progressList.append(df)
    
episode_reward_mean = []

for progress in progressList:
    episode_reward_mean.append(progress[['episode_reward_mean']].values)
    
for reward_mean in episode_reward_mean:
    plt.plot(reward_mean)

plt.xlabel('iteration')
plt.ylabel('mean reward')
plt.grid()
plt.title('Training PPO')
plt.ylim(0,400)
plt.xlim(0,300)
# Out:
# (0, 300)
